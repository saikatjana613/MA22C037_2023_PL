# %%
import pandas as pd
# %matplotlib inline

# %%
import yfinance as yf

# Define the list of ticker symbols
symbols = ['AAPL', 'GOOG', 'TSLA']

# Fetch data from Yahoo Finance
s = yf.download(symbols, start='2023-01-01')
# Out:
# [*********************100%%**********************]  3 of 3 completed

# %%
pip install yfinance
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# Tasks

# %%
# • Find out if a heirarchical indexing (MultiIndex) is being used in this data.

is_multiindex = isinstance(s.index, pd.MultiIndex)
print("Is MultiIndex being used in this data?", is_multiindex)
# Out:
# Is MultiIndex being used in this data? False

# %%
# • Access and plot the closing price of AAPL on all days in the data.

import matplotlib.pyplot as plt

aapl_closing = s['Adj Close']['AAPL']
aapl_closing.plot(title='AAPL Closing Prices')
plt.xlabel('Date')
plt.ylabel('Closing Price')
plt.show()

# %%
# • Print the closing price of all three stocks yesterday. 

# Find available dates in the index
available_dates = s.index.get_level_values(0).unique()

# Print available dates
print("Available dates in the DataFrame:")
print(available_dates)

# Select one of the available dates to check
date_to_check = '2023-10-06'  # Replace with an available date from the list

# Access and print the closing prices for the selected date
closing_prices = s.loc[date_to_check, 'Adj Close']
print("Closing prices of all three stocks on", date_to_check)
print(closing_prices)
# Out:
# Available dates in the DataFrame:
# DatetimeIndex(['2023-01-03', '2023-01-04', '2023-01-05', '2023-01-06',
#                '2023-01-09', '2023-01-10', '2023-01-11', '2023-01-12',
#                '2023-01-13', '2023-01-17',
#                ...
#                '2023-10-02', '2023-10-03', '2023-10-04', '2023-10-05',
#                '2023-10-06', '2023-10-09', '2023-10-10', '2023-10-11',
#                '2023-10-12', '2023-10-13'],
#               dtype='datetime64[ns]', name='Date', length=197, freq=None)
# Closing prices of all three stocks on 2023-10-06
# AAPL    177.490005
# GOOG    138.729996
# TSLA    260.529999
# Name: 2023-10-06 00:00:00, dtype: float64

# %%
# • Extract a smaller data frame with no MultiIndex containing only TSLA data. 

tsla_data = s['Adj Close']['TSLA'].reset_index()
print("\nDataFrame with TSLA data only:")
print(tsla_data)
# Out:
# DataFrame with TSLA data only:
#           Date        TSLA
# 0   2023-01-03  108.099998
# 1   2023-01-04  113.639999
# 2   2023-01-05  110.339996
# 3   2023-01-06  113.059998
# 4   2023-01-09  119.769997
# ..         ...         ...
# 192 2023-10-09  259.670013
# 193 2023-10-10  263.619995
# 194 2023-10-11  262.989990
# 195 2023-10-12  258.869995
# 196 2023-10-13  251.119995
#
# [197 rows x 2 columns]
